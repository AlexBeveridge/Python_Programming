# %%
"""
##############################################################################

Submission by: Alexander Beveridge
Data Science - Python - MBAN1 - Class of 2022 
Updated and Submitted: 2022-01-27

Docstring:

The North of England is known for its famous football teams, questionable
cuisine and hard to recognise language. But what about amateur terrorism?
Take a ride with four lions (humans) on their adventure into the world of 
terrorism.

Your purpose is to take a comical journey into planning a terrorist attack
within the U.K. 

Join the guys as they embark on their mission to preach God's will. You
start in a Pakistani jihadist camp. You are training using weapons supplied to
you and, in-turn, find a bazooka weapon.

I recommend watching a few clips of the film this is based on. I believe this
would be necessary to fully grasp the content of this adventure game.

This story is based on "Four Lions", a critically acclaimed satire on British 
Islamic terrorism. (131 words).

Movie free (with adverts): https://www.youtube.com/watch?v=gVRJ5hdc0W4

Five "Stages" Used (Defined as "Scenes"):

1. Start / Pakistani Training Camp
2. Council estate introduction (2.1)
3. House room (2.2)
4. Living room 
5. London

[Note: This does not include fail and win, as per the assignment requirements]

Bugs & Errors:

-- No Further Bugs Found --
-- No Further Errors Found -- 

##############################################################################
"""
## Code start ##

# Formatting options - adding options for colours and bold lettering.     
class colour:
    PURPLE = '\033[95m'
    CYAN = '\033[96m'
    DARKCYAN = '\033[36m'
    BLUE = '\033[94m'
    GREEN = '\033[92m'
    YELLOW = '\033[93m'
    RED = '\033[91m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
    END = '\033[0m'

# Import "random", "time" and "sys"; to be used within the game.
import random 
import time
import sys

# Allows endgame to exist.
from sys import exit

# Creating UDF for new print style which allows letters to appear to be typed in output.
def print_new(str):
    for letter in str:
        sys.stdout.write(letter)
        sys.stdout.flush()
        time.sleep(0.015)

## Start of game ##

# UDF for Start of game - this introduces the setting and context of the game.
def start(): 
    print(f"""
    
                                ╔╦╦╦═╦╗╔═╦═╦══╦═╗
    (⌐▀͡ ̯ʖ▀)︻̷┻̿═━               ║║║║╦╣╚╣╠╣║║║║║╦╣            ━╤デ╦︻(▀̿̿Ĺ̯̿̿▀̿ ̿)
                                ╚══╩═╩═╩═╩═╩╩╩╩═╝
    
    The North of England is known for its famous football teams, questionable
    cuisine and hard to recognise language. But what about amatuer terrorism?
    Take a ride with four lions(humans with fighting spirit) on their adventure 
                           into the world of terrorism.

    Join the guys as they embark on their mission to preach God's will. You
                      start in a Pakistani jihadist camp. """)
                      
    print_new(f"""
                    
    First of all, you notice a box in a donkey-drawn carriage. It seems to have a
   combination input on it and find a piece of paper next to it with the following:
    
                                   IF  1 = 3
                                       2 = 6
                                       3 = 9
                                       4 = 12
                                       5 = ?

            """) 
    
    # Creating defined variable for the answer of the riddle.
    answer = "15"
    answer = int(answer)
    
    # Use of while True when working out the answer of the riddle.
    while True:
        ans_attempt = input(prompt = f""" 
                 You decide to work out the code - What is your answer?
                                       - 15
                                       - 21
                                       - 12

                                        \n> """)
        # Insert the try and except function to cover any error that may appear.
        try:
            ans_attempt = int(ans_attempt)
            # Writing a conditional IF statement.
            if ans_attempt == int(answer):
                print_new(f""" 
            That is correct. You find a bazooka inside. Before you use it,
                               let us get to know you.
                                            """)
                training_camp()
                break # Use of break to continue through to the camp stage.
        
            # Adding an ELIF clause to the conidtional. 
            elif ans_attempt == int("21") or ans_attempt == int("12"):
                print_new(f"""
                    That is not the correct password, you failed at the first 
                                           attempt.
                    """)
                fail()
                break # Use of break to continue through to the fail stage.
        
            # Adding an ELSE clause to the conditional. 
            else:
                print_new(f""" That was not an answer given to you.""")
                continue # Use of continue to continue the while loop.
        
        # Insert the EXCEPT function for non-numerical or int inputs.   
        except ValueError:
            print(f""" Select only numbers. Please try again""")
            continue # Use of continue to continue the while loop.

        break # Use of break to stop the while loop.
                            

# UDF for Scene 1 surrounding the training camp - introduces names, characters and optional conditional scenes.
def training_camp():
    
    # Insert while True for conditional statement.
    while True:
        
        name = input(prompt = colour.BOLD + f"""
                     A good fighter needs a warrior-like name:
                 """ + colour.END) # Use of colour formatting.
        
        if len(name) == 0:
            print_new(f""" 
             Please type a name with character length bigger than 0 
                    """)
            continue # Continue loop if enter is pressed, using len() to identify length of word inputted.
    
    
        # Listing numbers to reject if inputted using ELIF conditional.
        elif "1" in name or "2" in name or "3" in name or "4" in name or "5" in name or "6" in name or "7" in name or "8" in name or "9" in name or "0" in name:
            print_new(f"""
        
            Last time I checked, a number was not a name. Maybe I am 
                        just behind the times. Try again..
        
            """)
            continue # Continue loop if an integer is inputted.
        
        # Else statement to give alternative to the IF.
        else:
            print (colour.PURPLE + f""" 
        
                                {name.title()}, let us begin. 
                        
                                                             """ + colour.END) # Curly brakcets used to repeat name that was inputted. 
    
            input(prompt = "<Lets put all that training to use - go and press enter.>")
            print(" ")
            break # Break while loop because name was what was expected.
            
    print(f"""
        {'*' * 70}""") # Multiplying '*' by 75 to include dividers in output.
    print(colour.BOLD + f"""
                                SCENE 1 - The Camp: 
                                                             """ + colour.END)
                                                             
    print_new(f"""
        You let Omar, a fellow trainee, know about your discovery. He picks up 
           the bazooka, a highly powerful ground to air missile system. In the 
            distance, you notice an American Drone doing surveillance in the 
                               area. Waj panics. """) # Intro for Scene 1.
            
    print_new(f"""
    
    Omar: Don't worry Waj, this is God's plan aint it. This is for jihad bro, for
                             the rubber dinghy rapids. 
            
     Waj:                 For the rubber dinghy rapids bro!
    
    """) # Dialouge 
    print(f"""
        {'*' * 70}""") # Divider. 
    
    # While true inserted to go back to input.
    while True:
        print_new(f"""
    
            The drone is getting nearer. you think back to the training you 
                        received the past week. Advise Omar to:
          
        1) Flippin' pop it brother.
        2) Think of the rubber dinghy rapids awaiting him.
        3) Put the weapon down, your fire power is nothing to that of the 
        great freedomland. 
        
        """) # Introducing conditions for first scene.
    
        option = input(prompt = "> ") # Input answer with prompt.
        
        # IF to eliminate counter argument.   
        if "don't" in option.lower() or "do not" in option.lower() or "dont" in option.lower():
            print(f"""
        {'*' * 70}""") # Divider.
            print_new(f"""
            Nice try Prof. Chase. You will not catch me out this easilly.
            """) # EASTER EGG 1
            input(prompt = "<Nice try... Press Enter.>")
            print(f"""
        {'*' * 70}""") # Divider.
            continue # Continue loop.
        
        # ELIF statement.
        elif option == "1" or "pop" in option.lower() or option.lower() == "one" or "shoot" in option.lower():
            print(f"""
        {'*' * 70}""") # Divider.
            print(f"""
        
                    Yourself and Waj count down for Omar to shoot.
        
        """)

            count = 3 # Identifying where to count from (assigning variable).
        
            # Creating while loop for count down.
            while count > 0:
                print(count)
                count = count - 1 # How much the original count should subtract by each second.
    
                time.sleep(1) # How long each count down should take.
        
            print(f"""
                  
                        ██████╗░░█████╗░░█████╗░███╗░░░███╗
                        ██╔══██╗██╔══██╗██╔══██╗████╗░████║
                        ██████╦╝██║░░██║██║░░██║██╔████╔██║
                        ██╔══██╗██║░░██║██║░░██║██║╚██╔╝██║
                        ██████╦╝╚█████╔╝╚█████╔╝██║░╚═╝░██║
                        ╚═════╝░░╚════╝░░╚════╝░╚═╝░░░░░╚═╝
            
            """) # Using text art for "BOOM".
            print(f"""
        {'*' * 70}""") # Divider.   
            print_new(""" 
            
         Omar shoots the weapon, but has armed it in the wrong direction. He 
         clearly did not listen in training camp and mistakenly takes down 
               a group of jihadis on the mountain behind him. 
      
                       Waj: Was that God's will bro? 
      
                      Omar: We gotta get out of here. 
      
      """) # Dialouge.
        
            input(prompt = "<This certainly wasn't God's Plan. Press Enter to get the hell out of there>")
            print(f"""
        {'*' * 70}""") # Divider.
            council_house()
            break # Transport to next scene and break the loop .
    
        # Start ELIF statement to allow different answers to be accounted for (option 2).
        elif option == "2" or "dinghy" in option.lower() or option.lower() == "two" or "think" in option.lower():
            print(f"""
        {'*' * 70}""") # Divider.
            print_new(f"""
        
                                  The Scene is set...
       Omar imagines the 10 degree weather in rainy England. He reminisces of the
        water park adventure ride at his local ammusement park. He feels the wind
             run through his hair, the water splashing against his face. 
        
        Unfortunately, Omar forgets he is in Jihadi occupied Pakistan, and sees
                a missle approaching him. He runs to the right but.......
                        
                       <<<<<<<<<<<<< Game Over >>>>>>>>>>>>>
        
        """)
            input(prompt = "<Press Enter>") # Input answer.
            print(f"""
        {'*' * 70}""") # Divider.
            fail()
            break # Transport to fail scene and break loop.
    
        # Secondary ELIF statement for option 3.
        elif option == "3" or option.lower() == "three" or "surrender" in option.lower() or "white flag" in option.lower() or "down" in option.lower():
            print(f"""
        {'*' * 70}""") # Divider.
            print_new(f"""
        
          You have let down your fellow jihads. We know you were not supposed 
          to do that, so we will give you another chance... Maybe change your 
                  name so that they do not recognise you this time.
        
        """)
            input(prompt = "<Press enter to get a second chance>")
            print(f"""
        {'*' * 70}""") # Divider.
            continue # continue loop.
            
        # Else statement to give absolute alternative to the IF.
        else:
            print(f"""
        {'*' * 70}""") # Divider. 
            print_new(f"""
        
            Urrrrrrrm... I dont think I understand what you mean here... try again...
        
        """) 
            print(f"""
        {'*' * 70}""") # Divider.
            continue # continue loop.
            
        break # break the loop.
        
# UDF for Scene 2, council house.       
def council_house():

    print(colour.BOLD + f"""
    
                            SCENE 2.1 - The House:
                                                             """ + colour.END)
    print_new(f"""
        After a dramatic and short lived life as a jiahdi, you and the gang 
        head back to the U.K. You reach the home of Barry, a white extremist
                who wants to take his beliefs to the next level.
    
        You start planning an attack. Your job is to choose what attack will 
                            be the most impactful.
    
    """) # Introduction to scene 2.
    
    input(prompt = '<Press Enter>')
    print(f"""
        {'*' * 70}""") # Divider. 
    house_room()

# Creating UDF for another room in the house. 
def house_room():
    
    # Insert While True.
    while True:
        print(colour.BOLD + f"""
    
                               What do you do?
                                                             """ + colour.END)
        print_new(f"""
        1) Blow up a Boots Pharmaceutical Store (Faisal's suggestion)
        2) The London Marathon (Omar's suggestion)
        3) You hear music in the living room, maybe I should check that out
           first?
        
        """) # Conditional options for scene 2.
        choice = input(prompt = "> ")
        print(f"""
        {'*' * 70}""") # Divider.
    
        # Insert IF statement.
        if "do not" in choice.lower() or "don't" in choice.lower() or "dont" in choice.lower():
            print_new(f"""
            Nice try Professor! You will not fool me!
            """) # EASTER EGG 2
            print(f"""
        {'*' * 70}""") # Divider.
            continue # continue loop.
            
        # Insert ELIF.    
        elif "1" in choice or "one" in choice.lower() or "boots" in choice.lower() or "faisal" in choice.lower():
            print_new(f"""
        
      Everyone stares at you... Omar states how Boots, despite its ridiculously 
      priced sandwiches, is not a worthwhile target. The others can't really
      believe your stupidity in picking Faisal's suggestion. But hey, they are
                    forgiving to their fellow brothers in arms. 
        
            """) # NOTICE: text is formatted with f""" to allow for correct spacing.
            input(prompt = "<Reconsider and return to the room with a more beleiveable option - Press Enter>")
            print(f"""
        {'*' * 70}""") # Divider.
            continue # continue the loop.
        
        # Insert ELIF statement.
        elif "2" in choice or "london" in choice.lower() or "two" in choice.lower() or "omar" in choice.lower():
            print_new(f"""
        
      Omar nods. He thinks this is a viable option. You all hear the noises 
      intensify in the other room. You all go to investigate what is going on.
                                    
                          It sounds like singing....
        
            """)
            input(prompt = "<Press Enter>") # Input Enter to proceed.
            print(f"""
        {'*' * 70}""") # Divider.
            living_room() # Transport to next scene.
            break # break the loop.
    
        # Insert ELIF statemnt.
        elif "3" in choice or "three" in choice.lower() or "music" in choice.lower() or "living" in choice.lower():
            print(colour.BOLD + f"""
    
                          SCENE 2.2a - The Living Room:
                                                             """ + colour.END)
            print_new(f"""
      You investigate the living room where the noise is coming from. You see 
      Hassan, a fellow comrade, singing to "Dancing in the Moonlight" with
      an oblivious neighbour, positioned next to a stock pile of explosives.
        
      You quickly get the neighbour out of the building, and immediately start
       to gather the explosives into plastic bags to take to another storage 
                                   facility.
                                   
          While on the way to facility, you confirm and decide the 
                      London Marathon is a great target.
        
            """) # Alternative outcome for living room scene - added London Marathon if decided to go see noise straight away.
            input(prompt = "<Press Enter>") # Input enter to proceed.
            print(f"""
        {'*' * 70}""") # Divider.
            london() # Transport to next scene. 
            break # break the loop. 
    
        # Insert ELIF for Easter Egg
        elif "sing" in choice.lower() or "dancing in the moonlight" in choice.lower():
            print(colour.YELLOW + f"""
        
        DaNcInG In ThE MoOnLiGhT ...
        
        ________________________________█████_____█████
        ______________________________███____██_██_____███
        _____________________________██________██__________██
        ____________________________██__________█____________██
        ________██████____________██________________________██
        _____███████████________██________________________██
        ____█████████████_______██_______________________██
        ___███████████████______██______________________██
        ___████████████████______██___________________██
        ___████████████████_______██_________________██
        ____███████████████_______███_______________██
        _______███████████_______██__██_____________██
        ___________███████______████___██__________██
        ____██████__██████████████_____██_____██
        __██████████████████████________██__██
        _████████████████████_____________████
        ██_█████_████████████_______________█
        █__█_██__████████████
        _____█__████████████
        _______█████████████
        _______██████████████
        _______███████████████
        ________███████████████
        _______███████__████████
        ______███████_____███████
        ____█████████________██████
                                                             """ + colour.END) # Format with colour yellow.
            print_new(f"""
        We loved your singing, but serioursly, go make a decision

            """) # EASTER EGG 3 - If you choose to sing dancing in the moonlight, you will recieve this.
            input(prompt = "<Press Enter>") # Press enter to proceed.
            print(f"""
        {'*' * 70}""") # Divider.
            continue # continue the loop.
    
        # Insert ELSE statement for alternative to IF/ELIF.
        else:
            print_new(f"""
        
        You are wasting time, im not sure why you even want to be on this mission.
       I suggest you take some time to learn basic grammer and spelling to complete
                                 this task again...
        
            """)
            input(prompt = "<Press Enter>") # Press enter to proceed.
            print(f"""
        {'*' * 70}""") # Divider.
            continue # Continue the loop.
            
        break # break the loop.

# UDF for living room scene.
def living_room():

    print(colour.BOLD + f"""
    
                        SCENE 2.2b - The Living Room:
                                                             """ + colour.END)
    print_new(f"""
    You investigate the living room where the noise is coming from. You see 
    Hassan, a fellow comrade, singing to "Dancing in the Moonlight" with
    an oblivious neighbour, positioned next to a stock pile of explosives.
        
    You quickly get the neighbour out of the building, and immediately start
    to gather the explosives into plastic bags to take to another storage 
                                 facility.
        
        """) # NOTICE: this text is different to the other living room outcome as London Marathon was already selected.
    input(prompt = "<Press Enter>") # Press enter to proceed.
    print(f"""
        {'*' * 70}""") # Divider.
    london() # Next scene.

def london():
    
    print(colour.BOLD + f"""
    
                         SCENE 3 - London Marathon:
                                                             """ + colour.END)
    print_new(f"""
    You have made it to the marathon in time. Wearing mascot costumes to 
    conceal your explosives, Omar as the Honey Monster; Waj as a man riding 
    an ostrich; Barry as a Teenage Mutant Ninja Turtle; and Hassan as an 
                    inverted clown, you prepare to attack
        
    Accidentally, in a panic, Barry sets off his mobile explosive device, 
    alerting police in the area. I wouldn't stand there if I was you, the
                           police are approaching! """) # Introduction to scene 3
    print(f"""
        
                               ╭━━━━━━━╮
                               ┃　　● ══　   ┃
                               ┃████████████┃
                               ┃████████████┃
                               ┃████████████┃
                               ┃████████████┃
                               ┃████████████┃
                               ┃████████████┃
                               ┃████████████┃
                               ┃████████████┃
                               ┃　　 　O　   ┃
                               ╰━━━━━━━╯
        
        """)
    input(prompt = "<Press Enter>") # Press enter to proceed.
    print(f"""
        {'*' * 70}""") # Divider.
    
    # Insert while True.
    while True:
        
        print_new(f"""
                 The police are shooting at you, try dodge the bullets!
            """) # Introduction of action sequence.
    
        # List of options that are randomised later on.
        police_shoot = ['*Bullet comes to your left*',
                  '*Bullet comes to your right*',
                  '*Bullet hits metal pole and goes towards your legs*',
                  '*Police man tries to get your from behind*',] # A list.
        
        evasion = random.choice(police_shoot) # Enhances replay value with random scenario from list.
        input(prompt = "<Incoming shot, you only have one chance to survive - Press Enter!>")
        print(f"""
        {'*' * 70}""") # Divider.
        print(evasion)
                
        # Insert IF    
        if evasion == police_shoot[0]:
            print_new(f"""
                    Inner-conscience: I have to avoid that bullet!
                
                              1. Swerve to your right.
                              2. Swerve to your left.
                              3. Jump up.
                              4. Run forward.
                  """) # Gives options if the first list item is chosen at random.
            print(f"""
        {'*' * 70}""") # Divider.
            movement = input(prompt = "> ") # Input Option.
                
            # Insert Nested conditional (IF).
            if "dont" in movement.lower() or "do not" in movement.lower() or "don't" in movement.lower():
                print_new(f"""
            Nice try Prof! Try not to break the code next time
                """)
                input(prompt = "< TRY AGAIN!>")
                print(f"""
        {'*' * 70}""") # Divider.
                continue # Continues the loop.
                    
            # Further nested conditional.
            elif "1" in movement or "one" in movement.lower() or "right" in movement.lower():
                print_new("""
                    Inner-conscience: Phew... that was close..
                      """)
                win() # Choose the right option, dodge the bullet, and win.
                break # break the loop.
                
            # Insert ELSE clause.
            else:
                print_new(f"""
                SPLAT. You are hit in your chest.. your time here
                                        is done.
                          """)
                input(prompt = "<Press enter to end.>") # Press enter to proceed.
                print(f"""
        {'*' * 70}""") # Divider.
                fail() # You died.
                break # break the loop.
                
        # Insert ELIF statement outside of inner-nested conditional.
        elif evasion == police_shoot[1]:
            print_new(f"""
            Inner-conscience: A bullet, to your right!!
                
                        1. Run forward.
                        2. Jump up.
                        3. Swerve to your left.
                        4. Swerve to your right.
                """) # Gives options if the second list item is chosen at random.
            print(f"""
        {'*' * 70}""") # Divider.
            movement = input(prompt = "> ") # Input choice.
                
            # Insert Nested conditional (IF).
            if "dont" in movement.lower() or "do not" in movement.lower() or "don't" in movement.lower():
                print_new(f"""
            Nice try Prof! Try not to break the code next time
                """)
                input(prompt = "< TRY AGAIN!>")
                print(f"""
        {'*' * 70}""") # Divider.
                continue # Continues the loop.
            
            # Continuing inner-nested conditional. 
            elif "3" in movement or "three" in movement.lower() or "left" in movement.lower():
                print_new(f"""
            Inner-conscience: Im like Neo in the matrix, a smooooooth operator.. 
                                                nice job!
                      """)
                print(f"""
        {'*' * 70}""") # Divider.
                win() # You win.
                break # break the loop.
        
            # Insert ELSE condtional. 
            else:
                print_new(f"""
                SPLAT. You are hit in your chest.. your time here
                                        is done.
                          """)
                input(prompt = "<Press enter to end.>") # Input enter to proceed.
                print(f"""
        {'*' * 70}""") # Divider.
                fail() # You died.
                break # break the loop.
                
        # Continuing Outer-nested conditional.    
        elif evasion == police_shoot[2]:
            print_new(f"""
            Inner-conscience: Woah, a bullet just refelected and is coming towards 
                                                    my legs!
                
                                  1. Run forward.
                                  2. Swerve to your right.
                                  3. Swerve to your left.
                                  4. Jump up.
                  """) # Gives options if the third list item is chosen at random.
            print(f"""
         {'*' * 70}""") # Divider.
            movement = input(prompt = "> ") # Input choice.
                
            # Insert Nested conditional (IF).
            if "dont" in movement.lower() or "do not" in movement.lower() or "don't" in movement.lower():
                print_new(f"""
            Nice try Prof! Try not to break the code next time
                """)
                input(prompt = "< TRY AGAIN!>")
                print(f"""
         {'*' * 70}""") # Divider.
                continue # Continues the loop.
                
            # Insert inner-IF.
            elif "4" in movement or "four" in movement.lower() or "jump" in movement.lower():
                print_new(f"""
            Inner-conscience: That was way too close for comfort, 
                                      will there be more?
                      """)
                print(f"""
         {'*' * 70}""") # Divder.
                win() # You win.
                break # break the loop.
                
            # Insert ELSE clause. 
            else:
                print_new(f"""
                        SPLAT. You are hit in your leg.. your time here
                                              is done.
                          """)
                input(prompt = "<Press enter to end.>") # Press enter to continue.
                print(f"""
         {'*' * 70}""") # Divider.
                fail() # You died.
                break # break the loop.
                
        # Continuing outer-nested conditional.    
        elif evasion == police_shoot[3]:
            print_new(f"""
            Inner-conscience: My senses tell me someone is coming behind me..
                
                                1. Jump up.
                                2. Swerve to your right.
                                3. Swerve to your left.
                                4. Run forward.
                  """) # Gives options if the fourth list item is chosen at random.
            print(f"""
         {'*' * 70}""") # Divider.
            movement = input(prompt = "> ") # Insert option.
                
            # Insert Nested conditional (IF).
            if "dont" in movement.lower() or "do not" in movement.lower() or "don't" in movement.lower():
                print_new(f"""
            Nice try Prof! Try not to break the code next time
                """)
                input(prompt = "< TRY AGAIN!>")
                print(f"""
         {'*' * 70}""") # Divider.
                continue # Continues the loop.
            
            # Inner-nested conditional.
            elif "4" in movement or "four" in movement.lower() or "forward" in movement.lower() or "run" in movement.lower():
                print(f"""
                Inner-conscience: They will never catch me bro.
                      """)
                print(f"""
         {'*' * 70}""") # Divider.
                win() # You win.
                break # break the loop.
            
        # ELSE clause added.
        else:
            print_new(f"""
                    SPLAT. You are hit in your chest.. your time here
                                        is done.
                          """)
            input(prompt = "<Press enter to end.>")
            print(f"""
         {'*' * 70}""") # Divider.
            fail() # You died.
            break # Breaks the loop.
                
        break # Breaks entire loop.

# UDF for win function.
def win():
    
    print_new(colour.RED + colour.BOLD + f"""
    
    < - >< - >< - >< - >< - >< - < THE END > - >< - >< - >< - >< - >< - >< - >
    
    CONGRATULATIONS!!! You have succesfully completed your mission. You evaded 
    the police, at the cost of your fellow partners in crime, but you are now 
          destined a better life. No winner walks away without a prize..
    
    
        To celebrate: a ticket to the rubber dinghy rapids. Thank me later.
    
    < - >< - >< - >< - >< - >< - < THE END > - >< - >< - >< - >< - >< - >< - >
        
                                                             """ + colour.END) # End statement if you win.
    print(f"""
        {'*' * 70}""") # Divider.
    
    # While loop for correct input.
    while True:
        print(f"""
                Would you like to play this epic adventure again?
                                 1. Yes (y)
                                 2. No  (n)
           """) # Option to play again to increase replay value.
    
        option = input(prompt = "> ") # Input choice.
    
        # Start IF conditional.
        if "1" in option or "one" in option.lower() or "y" in option.lower():
            start() # Return to beginning to replay game.
        
        # Adding ELIF   
        elif "2" in option or "two" in option.lower() or "n" in option.lower():
            exit(0) # Exit function to stop the game from functioning. 
        
        else: 
            print_new(f"""
        
            I have had enough of you trying to play around with this. 
             you either press 1 - ONE - or 2 - TWO... Its not hard..
            
            """) # Another chance to input correctly.
            input(prompt = "<Press Enter>") # Press enter to proceed.
            print(f"""
        {'*' * 70}""") # Divider.
            continue # continue loop.
            
        break # Breaks loop if conditional is met.
        
# UDF for failure (boooooo..).    
def fail():
    
    print_new(f"""
        For whatever reason, you decided to fail. I would say I am disapointed in you,
                   but what do you expect from someone with that name.
    
        If you want to try again, press '1'. If you try play funny business and type
                anything apart from '1', you will be permanently eliminated.
    
    """) # If 1 is not pressed, game will not function any longer.
    print(f"""
        {'*' * 70}""") # Divider.
    
    option = input(prompt = "> ")
    
    if "1" in option:
        start() # Play again.
        
    else:
        exit(0) # Stops game entirely.

start() # End UD function to return to start.
# Out:
#
#                                 ╔╦╦╦═╦╗╔═╦═╦══╦═╗
#     (⌐▀͡ ̯ʖ▀)︻̷┻̿═━               ║║║║╦╣╚╣╠╣║║║║║╦╣            ━╤デ╦︻(▀̿̿Ĺ̯̿̿▀̿ ̿)
#                                 ╚══╩═╩═╩═╩═╩╩╩╩═╝
#
#     The North of England is known for its famous football teams, questionable
#     cuisine and hard to recognise language. But what about amatuer terrorism?
#     Take a ride with four lions(humans with fighting spirit) on their adventure
#                            into the world of terrorism.
#
#     Join the guys as they embark on their mission to preach God's will. You
#                       start in a Pakistani jihadist camp.
#
#
#     First of all, you notice a box in a donkey-drawn carriage. It seems to have a
#    combination input on it and find a piece of paper next to it with the following:
#
#                                    IF  1 = 3
#                                        2 = 6
#                                        3 = 9
#                                        4 = 12
# ...
